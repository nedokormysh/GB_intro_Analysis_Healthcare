# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/GB_intro_Analysis_Healthcare/blob/lesson_3/GB_intro_Healthcare_Analysis_hw_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Условие.
#
# Урок 3. Data Science: разработке и тестировании лекарств
#
# В онлайн-инструментах (и не только) используются данные о химических веществах в формате SMILES. Обычно он используется для описания структуры химических молекул. SMILES - это аббревиатура от Simplified Molecular Input Line Entry Specification.
#
# Все основные данные о веществах можно найти в базе данных PubChem. PubChem в основном содержит небольшие молекулы, но также и более крупные молекулы, такие как нуклеотиды, углеводы, липиды, пептиды и химически модифицированные макромолекулы. Также есть информация о химических структурах, идентификаторах, химических и физических свойствах, биологической активности, патентах, данных о здоровье, безопасности, токсичности и многом другом.
# Некоторые инструменты для предсказания мишеней:
#
# ● SwissTargetPrediction - позволяет оценить наиболее вероятные макромолекулярные мишени небольшой молекулы, предполагаемой как биологически активная. Предсказание основано на сочетании двухмерного и трехмерного сходства с библиотекой из 370 000 известных активных веществ для более чем 3000 белков трех разных видов.
#
# ● Super-PRED - веб-сервер прогнозирования соединений, основанный на модели машинного обучения с использованием логистической регрессии.
#
# ● Tools4miRs - представляет собой веб-мета-сервер прогнозирования целей, включающий определяемые пользователем методы прогнозирования целей при анализе предоставленных пользователями данных.
#
# Найдите в интернете лекарство, вышедшее из употребления, сделайте поиск его структуры по химическим базам данных. Затем с помощью одного из описанных выше тулов предскажите мишени для этого лекарства. Изучите найденные мишени и предположите, какие заболевания может лечить данное лекарство при взаимодействии с предсказанными мишенями.

# %% [markdown]
# # Решение.

# %% [markdown]
# ## Вещество

# %% [markdown]
# **Рассмотрим вещество:**  Фенилпропаноламин (Phenylpropanolamine).
#
# Википедия(рус):
# Фенилпропанолами́н (норэфедри́н) — адреномиметическое лекарственное средство, которое используется также в качестве противоотёчного средства для носа и как средство для подавления аппетита(контроля веса).
#
# Wikipedia(eng.)
# Phenylpropanolamine (PPA) is a sympathomimetic agent which is used as a decongestant and appetite suppressant. It was commonly used in prescription and over-the-counter cough and cold preparations. In veterinary medicine, it is used to control urinary incontinence in dogs.
#
# Судя по сообщениям вещество уже не используется во большом количестве стран, либо не рекомендовано к использованию из-за опасения риска инсульта.

# %% [markdown]
# ## Pubchem

# %% [markdown]
# Pubchem: https://pubchem.ncbi.nlm.nih.gov/compound/26934
#
# CC(C(C1=CC=CC=C1)O)N

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Мишени

# %% [markdown]
# ### SwissTargetPrediction
#
# http://www.swisstargetprediction.ch/result.php?job=398012845&organism=Homo_sapiens

# %%
import pandas as pd

# %%
df_0 = pd.read_csv('https://raw.githubusercontent.com/nedokormysh/GB_intro_Analysis_Healthcare/lesson_3/SwissTargetPrediction.csv')
df_0.head(15)
# Out:
#                                                Target Common name Uniprot ID  \
# 0                        Alpha-2a adrenergic receptor      ADRA2A     P08913
# 1        Alpha-2b adrenergic receptor   (by homology)      ADRA2B     P18089
# 2        Alpha-1a adrenergic receptor   (by homology)      ADRA1A     P35348
# 3                               Serotonin transporter      SLC6A4     P31645
# 4                   Trace amine-associated receptor 1       TAAR1     Q96RJ0
# 5                                Dopamine transporter      SLC6A3     Q01959
# 6                          Norepinephrine transporter      SLC6A2     P23975
# 7                      Serotonin 2a (5-HT2a) receptor       HTR2A     P28223
# 8                                    Aminopeptidase N       ANPEP     P15144
# 9               Lysine-specific histone demethylase 1       KDM1A     O60341
# 10                     Serotonin 3a (5-HT3a) receptor       HTR3A     P46098
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Большая часть (33.3%) мишеней принадлежит классу адренергические рецепторов.
#
# Альфа-2-адренергические рецепторы являются членами суперсемейства рецепторов, связанных с G-белком. Альфа-2-адренорецепторы представляют собой тип адренергических рецепторов (адреналина или адреналина), которые ингибируют аденилатциклазу. Эти рецепторы включают 3 высоко гомологичных подтипа: альфа2А, альфа2В и альфа2С.
# Они участвуют в регуляции высвобождения молекул нейромедиаторов из симпатических нервов и адренергических нейронов центральной нервной системы.
#
# * 26.7% - транспортных белков
#
# * 13.3% - протеазы

# %% [markdown]
# ### Super-PRED
#
# Не уверен, что вообще правильно воспользовался. Как-то странно оно работало.
#
# Скрин веществ с вероятностью больше 80 %.

# %%
df_1 = pd.read_csv('https://raw.githubusercontent.com/nedokormysh/GB_intro_Analysis_Healthcare/lesson_3/Targets.csv')
df_1.head(15)
# Out:
#                                           Target Name      ChEMBL-ID  \
# 0                       G-protein coupled receptor 55  CHEMBL1075322
# 1              Nuclear factor NF-kappa-B p105 subunit     CHEMBL3251
# 2                                         Cathepsin D     CHEMBL2581
# 3                                    Cyclooxygenase-1      CHEMBL221
# 4                     Tyrosyl-DNA phosphodiesterase 1  CHEMBL1075138
# 5                Muscarinic acetylcholine receptor M5     CHEMBL2035
# 6           Transcription intermediary factor 1-alpha  CHEMBL3108638
# 7                Muscarinic acetylcholine receptor M4     CHEMBL1821
# 8   Endoplasmic reticulum-associated amyloid beta-...     CHEMBL4159
# 9                        Proteasome Macropain subunit     CHEMBL3492
# 10          DNA-(apurinic or apyrimidinic site) lyase     CHEMBL5619
# 11                             Bloom syndrome protein  CHEMBL1293237
# 12                       Glutathione S-transferase Pi     CHEMBL3902
# ...

# %% [markdown]
# 3 самых вероятных мишени:
#
# * рецепторы, связанные с G-белком
# * NFKB1 - Транскрипционный фактор
# * катепсин D - протеаза

# %% [markdown]
# В принципе, результаты по мишеням достаточно близки.

# %% [markdown]
# Базой Tools4miRs воспользоваться у меня не получилось.

# %% [markdown]
# ## Подбор болезней

# %% [markdown]
# Симпатическая нервная система регулирует сердечно-сосудистую функцию, активируя адренергические рецепторы в сердце, кровеносных сосудах и почках.
#
# Вероятно можно предположить, что у нас должны найтись какие-нибудь болезни, связанные с сердечно-сосудистой функцией. Возможно с артериальным давлением.

# %% [markdown]
# ### ADRA2A, ADRA2B, ADRA2C

# %% [markdown]
# #### Protein
#
# https://www.ncbi.nlm.nih.gov/protein/NP_000672.3

# %% [markdown]
# A clear association between the alpha-2-adrenergic receptor and disease has not been yet established.
#
# Судя по этой записи, то всё таки взаимосвязь между болезнями и адренергическими рецепторами пока не обнаружена.
#
# Но в принципе есть исследование https://pubmed.ncbi.nlm.nih.gov/34965503/ ('The α2-adrenergic receptor pathway modulating depression influences the risk of arterial thrombosis associated with BDNFVal66Met polymorphism'), в нём утверждается, что разработка ингибиторов ADRA2A может представлять собой лечение тромботических состояний, связанных с депрессией.
#
# Этого не совсем понял, но вроде бы мы получили требуемую болезнь.

# %% [markdown]
# #### KEGG
#
# Не совсем понял как искать болезни, да и путей нашёл только 2.
#
# (https://www.kegg.jp/medicus-bin/search_medicus?q=ADRA2A&display=disease&from=disease)
#
# https://www.kegg.jp/kegg-bin/search_pathway_text?map=hsa&keyword=ADRA2A&mode=1&viewImage=true
#
#
# * hsa04022 (Сигнальный путь cGMP-PKG)
# * hsa04080 (Нейроактивные лиганд-рецепторные взаимодействия)
#
# Но вроде бы в kegg нет болезней

# %% [markdown]
# ### Cathepsin D

# %% [markdown]
# И рассмотрим, например, катепсин Д - протеаза, полученная из super-PRED

# %% [markdown]
# #### Protein

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/protein/AAD13868.1

# %% [markdown]
# Gene database https://www.ncbi.nlm.nih.gov/gene/1509
#
# This enzyme exhibits pepsin-like activity and plays a role in protein turnover and in the proteolytic activation of hormones and growth factors. Mutations in this gene play a causal role in neuronal ceroid lipofuscinosis-10 and may be involved in the pathogenesis of several other diseases, including breast cancer and possibly Alzheimer's disease.
#
# Возможно у нас есть взаимосвязь с онкологическими заболеваниями.

# %% [markdown]
# #### KEGG

# %% [markdown]
# Здесь нашлось 7 путей
#
# https://www.kegg.jp/kegg-bin/search_pathway_text?map=hsa&keyword=CTSD&mode=1&viewImage=true
#
# Отметим:
# * hsa04210 (апоптоз)
# * hsa04142 (здесь в название лизосома)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В разделе болезней нашлось https://www.kegg.jp/entry/H02279 - дефицит катепсина Д.

# %% [markdown]
# Но стоит отметить, что вероятно, что лучше ориентироваться на результаты мишеней из swiss target prediction
